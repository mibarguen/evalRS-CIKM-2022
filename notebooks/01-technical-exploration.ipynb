# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, '../')

# %%
import numpy as np
import pandas as pd

from dotenv import load_dotenv

load_dotenv('../upload.env')

EMAIL = os.getenv('EMAIL')  # the e-mail you used to sign up
assert EMAIL != '' and EMAIL is not None
BUCKET_NAME = os.getenv('BUCKET_NAME') # you received it in your e-mail
PARTICIPANT_ID = os.getenv('PARTICIPANT_ID') # you received it in your e-mail
AWS_ACCESS_KEY = os.getenv('AWS_ACCESS_KEY') # you received it in your e-mail
AWS_SECRET_KEY = os.getenv('AWS_SECRET_KEY') # you received it in your e-mail

# %%
pd.set_option('display.max_column', None)

# %%
from evaluation.EvalRSRunner import EvalRSRunner
from evaluation.EvalRSRunner import ChallengeDataset
from reclist.abstractions import RecModel

# %%
LIMIT = 10

# %%
class MyModel(RecModel):
    
    def __init__(self, items: pd.DataFrame, top_k: int=100, **kwargs):
        super(MyModel, self).__init__()
        self.items = items
        self.top_k = top_k
        # kwargs may contain additional arguments in case, for example, you
        # have data augmentation strategies
        print("Received additional arguments: {}".format(kwargs))
        return

    def train(self, train_df: pd.DataFrame):
        """
        Implement here your training logic. Since our example method is a simple random model,
        we actually don't use any training data to build the model, but you should ;-)

        At the end of training, make sure the class contains a trained model you can use in the predict method.
        """
        print(train_df.head(1))
        print("Training completed!")
        return 

    def predict(self, user_ids: pd.DataFrame) -> pd.DataFrame:
        """
        
        This function takes as input all the users that we want to predict the top-k items for, and 
        returns all the predicted songs.

        While in this example is just a random generator, the same logic in your implementation 
        would allow for batch predictions of all the target data points.
        
        """
        k = self.top_k
        num_users = len(user_ids)
        pred = self.items.sample(n=k*num_users, replace=True).index.values
        pred = pred.reshape(num_users, k)
        pred = np.concatenate((user_ids[['user_id']].values, pred), axis=1)
        return pd.DataFrame(pred, columns=['user_id', *[str(i) for i in range(k)]]).set_index('user_id')

# %%
dataset = ChallengeDataset(force_download=False)
# Out:
# LFM dataset already downloaded. Skipping download.
# Loading dataset.
# Generating folds.
# Generating dataset hashes.

# %%
train, test = dataset.get_sample_train_test()

# %%
my_model = MyModel(
    items=dataset.df_tracks,
    my_custom_argument='my_custom_argument' 
)
# Out:
# Received additional arguments: {'my_custom_argument': 'my_custom_argument'}

# %%
class CustomRunner(EvalRSRunner):
    def __init__(self,
                 dataset: ChallengeDataset,
                 email: str = None,
                 participant_id: str = None,
                 aws_access_key_id: str = None,
                 aws_secret_access_key: str = None,
                 bucket_name: str = None):
        super().__init__(
                 dataset,
                 email,
                 participant_id,
                 aws_access_key_id,
                 aws_secret_access_key,
                 bucket_name)
        
    def evaluate(
        self,
        model,
        seed: int = None,
        upload: bool = True,
        limit: int = 0,
        custom_RecList = None,
        debug=True,
        **kwargs):

        return super().evaluate(model,
                seed,
                upload,
                limit,
                custom_RecList,
                debug
                        )

# %%
custom_runner = CustomRunner(
    dataset=dataset,
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY,
    participant_id=PARTICIPANT_ID,
    bucket_name=BUCKET_NAME,
    email=EMAIL
    )

# %%
r = custom_runner.evaluate(model=my_model, limit=LIMIT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 r = custom_runner.evaluate(model=my_model, limit=LIMIT)
#
# NameError: name 'my_model' is not defined

# %% [markdown]
# ## Create complete dataset

# %%
dataset.df_tracks
# Out:
#                        track  artist_id               artist  \
# track_id
# 1           A Matter of Time          3         Foo Fighters
# 2                  Hangar 18          1             Megadeth
# 3           Up the Downstair          4       Porcupine Tree
# 5                   Mixtaped          5               No-Man
# 6         Sounds that I Hear          6               Airbag
# ...                      ...        ...                  ...
# 32244852      Cotton Eye Joe      10641               Rednex
# 32250955           Hot Stuff       2949         Donna Summer
# 32253071            Candyman        326   Christina Aguilera
# 32275309    One (Radio Edit)       2322  Swedish House Mafia
# 32282895        Troublemaker       9699            Olly Murs
#
#                                                   albums_id  \
# track_id
# 1         [1, 67655, 605875, 682938, 889936, 2797722, 34...
# 2         [2, 693, 821, 2113, 12071, 13309, 17004, 83531...
# 3         [84, 116, 13570, 283314, 302086, 303154, 35956...
# 5                                              [5, 7654681]
# 6                                         [6, 340, 1139848]
# ...                                                     ...
# 32244852                          [93769, 941156, 10112520]
# 32250955           [120851, 127382, 217400, 256358, 712567]
# 32253071                                     [36723, 37494]
# 32275309                                            [32033]
# 32282895  [35397, 175578, 680866, 2469369, 4483467, 1178...
#
#                                                      albums
# track_id
# 1         ['Wasting Light', 'Wasting Light (Deluxe Versi...
# 2         ['Rust In Peace', 'Countdown To Extinction', '...
# 3         ['Up the Downstair', 'Coma Divine', 'Up The Do...
# 5         ['Schoolyard Ghosts', 'Schoolyard Ghosts Disc 1']
# 6                   ['Sounds That I Hear', 'Identity', nan]
# ...                                                     ...
# 32244852  ["100 Hits Of The '90s", 'Sex & Violins', 'Q M...
# 32250955  ['On the Radio (Greatest Hits)', 'Endless Summ...
# 32253071               ['Back to Basics', 'Back to Basics']
# 32275309               ['One (Your Name) [feat. Pharrell]']
# 32282895  ['Troublemaker', 'The Dome, Volume 65', 'Right...
#
# [820998 rows x 5 columns]

# %% [markdown]
# ## Create Complete Dataset

# %%
train.head()
# Out:
#        user_id  artist_id  album_id  track_id   timestamp  user_track_count
# 43142  7438644       1312      2944      8507  1354982620                 1
# 43143  7438644       1312      2944      8508  1354982427                 1
# 43144  7438644       1312      2944      8509  1354982287                 1
# 43145  7438644       1312      2944      8510  1354981997                 1
# 43149  7438644       1313      2946      8514  1354981396                 1

# %%
dataset.df_users
# Out:
#          country  age gender  playcount  registered_unixtime  country_id  \
# user_id
# 384           UK   35      m      42139           1035849600           0
# 1206         NaN   -1      n      33103           1035849600          -1
# 2622         NaN   -1    NaN       2030           1037404800          -1
# 2732         NaN   -1      n        147           1037577600          -1
# 3653          UK   31      m      18504           1041033600           0
# ...          ...  ...    ...        ...                  ...         ...
# 50871714      BY   19      f        569           1342728447          55
# 50900118      RU   19      m         96           1342887305          12
# 50931921     NaN   -1      m        221           1343064308          -1
# 50933471     NaN   -1      n         49           1343071062          -1
# 50967444     NaN   16      n        262           1343250546          -1
#
#           gender_id  novelty_artist_avg_month  novelty_artist_avg_6months  \
# user_id
# 384               0                  0.276629                    0.044439
# 1206              1                  0.437224                    0.109671
# 2622             -1                  0.604828                    0.043923
# 2732              1                  0.756973                    0.020071
# 3653              0                  0.380005                    0.045207
# ...             ...                       ...                         ...
# 50871714          2                  0.417087                    0.035417
# 50900118          0                  0.566328                    0.032624
# 50931921          0                  0.483171                    0.032946
# 50933471          1                  0.559632                    0.026570
# 50967444          1                  0.263945                    0.059712
#
#           novelty_artist_avg_year  mainstreaminess_avg_month  \
# user_id
# 384                      0.309429                   0.024655
# 1206                     0.513787                   0.181991
# 2622                     0.698983                   0.052310
# 2732                     0.882801                   0.005092
# 3653                     0.424411                   0.042821
# ...                           ...                        ...
# 50871714                 0.549888                   0.084304
# 50900118                 0.680317                   0.049010
# 50931921                 0.351648                   0.038075
# 50933471                 0.599199                   0.040033
# 50967444                 0.512946                   0.115332
#
#           mainstreaminess_avg_6months  mainstreaminess_avg_year  \
# user_id
# 384                          0.367343                  0.000000
# 1206                         0.391304                  0.000000
# 2622                         0.780064                  0.079669
# 2732                         0.886364                  0.032614
# 3653                         0.491756                  0.077731
# ...                               ...                       ...
# 50871714                     0.662491                  0.075544
# 50900118                     0.827854                  0.103613
# 50931921                     0.382353                  0.012505
# 50933471                     0.656787                  0.039335
# 50967444                     0.701197                  0.089394
#
#           mainstreaminess_global  cnt_listeningevents  cnt_distinct_tracks  \
# user_id
# 384                     0.124903              17198.0               3601.0
# 1206                    0.343855              17967.0              10990.0
# 2622                    0.245980               3939.0               3084.0
# 2732                    0.077512                234.0                202.0
# 3653                    0.207567              18238.0               9839.0
# ...                          ...                  ...                  ...
# 50871714                0.160736              26932.0               6837.0
# 50900118                0.145418               7174.0               3970.0
# 50931921                0.136102                998.0                676.0
# 50933471                0.175908               4152.0               2845.0
# 50967444                0.247454              34440.0              10080.0
#
#           cnt_distinct_artists  cnt_listeningevents_per_week  \
# user_id
# 384                      330.0                      196.2290
# 1206                    1693.0                      265.1490
# 2622                    1176.0                       22.8009
# 2732                     112.0                        1.1455
# 3653                    2151.0                       41.8051
# ...                        ...                           ...
# 50871714                1154.0                      244.3810
# 50900118                 547.0                       76.4347
# 50931921                 155.0                       12.9569
# 50933471                 475.0                       38.5342
# 50967444                 686.0                      314.1850
#
#           relative_le_per_weekday1  relative_le_per_weekday2  \
# user_id
# 384                         0.1828                    0.1513
# 1206                        0.1679                    0.1850
# 2622                        0.1813                    0.1318
# 2732                        0.0214                    0.0726
# 3653                        0.1164                    0.1545
# ...                            ...                       ...
# 50871714                    0.1765                    0.1437
# 50900118                    0.1398                    0.1280
# 50931921                    0.2695                    0.0341
# 50933471                    0.1419                    0.1202
# 50967444                    0.1298                    0.1414
#
#           relative_le_per_weekday3  relative_le_per_weekday4  \
# user_id
# 384                         0.1361                    0.1252
# 1206                        0.1815                    0.1640
# 2622                        0.1181                    0.1442
# 2732                        0.0940                    0.2778
# 3653                        0.1316                    0.1380
# ...                            ...                       ...
# 50871714                    0.1091                    0.1272
# 50900118                    0.1310                    0.1469
# 50931921                    0.0932                    0.1453
# 50933471                    0.1525                    0.1185
# 50967444                    0.1477                    0.1380
#
#           relative_le_per_weekday5  relative_le_per_weekday6  \
# user_id
# 384                         0.1318                    0.1286
# 1206                        0.1542                    0.0700
# 2622                        0.1775                    0.1084
# 2732                        0.0171                    0.2564
# 3653                        0.1580                    0.1745
# ...                            ...                       ...
# 50871714                    0.1750                    0.1444
# 50900118                    0.1450                    0.1415
# 50931921                    0.0611                    0.0992
# 50933471                    0.1373                    0.1168
# 50967444                    0.1441                    0.1545
#
#           relative_le_per_weekday7  relative_le_per_hour0  \
# user_id
# 384                         0.1443                 0.0850
# 1206                        0.0773                 0.0539
# 2622                        0.1389                 0.0074
# 2732                        0.2607                    NaN
# 3653                        0.1270                 0.0612
# ...                            ...                    ...
# 50871714                    0.1241                 0.0568
# 50900118                    0.1678                 0.0375
# 50931921                    0.2976                    NaN
# 50933471                    0.2129                 0.0539
# 50967444                    0.1445                 0.0650
#
#           relative_le_per_hour1  relative_le_per_hour2  relative_le_per_hour3  \
# user_id
# 384                      0.1169                 0.1101                 0.0984
# 1206                     0.0371                 0.0321                 0.0245
# 2622                     0.0053                 0.0036                 0.0005
# 2732                        NaN                    NaN                    NaN
# 3653                     0.0392                 0.0249                 0.0250
# ...                         ...                    ...                    ...
# 50871714                 0.0440                 0.0292                 0.0197
# 50900118                 0.0162                 0.0057                 0.0163
# 50931921                 0.0010                    NaN                    NaN
# 50933471                 0.0349                 0.0248                 0.0084
# 50967444                 0.0711                 0.0913                 0.0947
#
#           relative_le_per_hour4  relative_le_per_hour5  relative_le_per_hour6  \
# user_id
# 384                      0.0781                 0.0500                 0.0145
# 1206                     0.0322                 0.0368                 0.0366
# 2622                     0.0003                 0.0008                 0.0003
# 2732                        NaN                    NaN                    NaN
# 3653                     0.0169                 0.0105                 0.0088
# ...                         ...                    ...                    ...
# 50871714                 0.0138                 0.0111                 0.0118
# 50900118                 0.0114                 0.0121                 0.0107
# 50931921                    NaN                    NaN                    NaN
# 50933471                 0.0007                 0.0010                 0.0022
# 50967444                 0.0746                 0.0534                 0.0362
#
#           relative_le_per_hour7  relative_le_per_hour8  relative_le_per_hour9  \
# user_id
# 384                      0.0051                 0.0006                 0.0012
# 1206                     0.0460                 0.0257                 0.0041
# 2622                     0.0003                 0.0008                 0.0025
# 2732                        NaN                 0.0128                 0.0342
# 3653                     0.0063                 0.0086                 0.0206
# ...                         ...                    ...                    ...
# 50871714                 0.0140                 0.0176                 0.0265
# 50900118                 0.0110                 0.0360                 0.0407
# 50931921                    NaN                    NaN                 0.0130
# 50933471                    NaN                    NaN                 0.0026
# 50967444                 0.0226                 0.0145                 0.0083
#
#           relative_le_per_hour10  relative_le_per_hour11  \
# user_id
# 384                       0.0079                  0.0051
# 1206                      0.0014                     NaN
# 2622                      0.0279                  0.0678
# 2732                      0.0342                  0.1410
# 3653                      0.0117                  0.0198
# ...                          ...                     ...
# 50871714                  0.0314                  0.0420
# 50900118                  0.0514                  0.0489
# 50931921                  0.0190                  0.0641
# 50933471                  0.0079                  0.0282
# 50967444                  0.0070                  0.0069
#
#           relative_le_per_hour12  relative_le_per_hour13  \
# user_id
# 384                       0.0091                  0.0209
# 1206                         NaN                  0.0003
# 2622                      0.0675                  0.1285
# 2732                      0.1154                  0.1368
# 3653                      0.0434                  0.0495
# ...                          ...                     ...
# 50871714                  0.0554                  0.0567
# 50900118                  0.0473                  0.0415
# 50931921                  0.0832                  0.0681
# 50933471                  0.0537                  0.0354
# 50967444                  0.0070                  0.0084
#
#           relative_le_per_hour14  relative_le_per_hour15  \
# user_id
# 384                       0.0279                  0.0410
# 1206                      0.0016                  0.0115
# 2622                      0.1320                  0.0493
# 2732                      0.0598                  0.0726
# 3653                      0.0541                  0.0518
# ...                          ...                     ...
# 50871714                  0.0542                  0.0529
# 50900118                  0.0397                  0.0431
# 50931921                  0.0561                  0.1172
# 50933471                  0.0417                  0.0347
# 50967444                  0.0153                  0.0292
#
#           relative_le_per_hour16  relative_le_per_hour17  \
# user_id
# 384                       0.0811                  0.1506
# 1206                      0.0276                  0.0662
# 2622                      0.0317                  0.0470
# 2732                      0.0171                  0.0342
# 3653                      0.0564                  0.0554
# ...                          ...                     ...
# 50871714                  0.0575                  0.0558
# 50900118                  0.0587                  0.0733
# 50931921                  0.1723                  0.1062
# 50933471                  0.0294                  0.0236
# 50967444                  0.0422                  0.0438
#
#           relative_le_per_hour18  relative_le_per_hour19  \
# user_id
# 384                       0.0377                  0.0298
# 1206                      0.0790                  0.0838
# 2622                      0.0658                  0.1127
# 2732                      0.0769                  0.1453
# 3653                      0.0849                  0.0954
# ...                          ...                     ...
# 50871714                  0.0578                  0.0573
# 50900118                  0.0843                  0.0764
# 50931921                  0.0892                  0.1092
# 50933471                  0.0508                  0.0763
# 50967444                  0.0547                  0.0508
#
#           relative_le_per_hour20  relative_le_per_hour21  \
# user_id
# 384                       0.0132                  0.0007
# 1206                      0.0995                  0.1195
# 2622                      0.1112                  0.0680
# 2732                      0.0470                  0.0513
# 3653                      0.0833                  0.0657
# ...                          ...                     ...
# 50871714                  0.0515                  0.0551
# 50900118                  0.0728                  0.0643
# 50931921                  0.0621                  0.0120
# 50933471                  0.1086                  0.1419
# 50967444                  0.0428                  0.0460
#
#           relative_le_per_hour22  relative_le_per_hour23
# user_id
# 384                       0.0001                  0.0151
# 1206                      0.0968                  0.0839
# 2622                      0.0437                  0.0254
# 2732                      0.0085                  0.0128
# 3653                      0.0471                  0.0595
# ...                          ...                     ...
# 50871714                  0.0639                  0.0641
# 50900118                  0.0555                  0.0452
# 50931921                  0.0210                  0.0060
# 50933471                  0.1387                  0.1004
# 50967444                  0.0575                  0.0568
#
# [119555 rows x 49 columns]

# %%
dataset.df_users
# Out:
#          country  age gender  playcount  registered_unixtime  country_id  \
# user_id
# 384           UK   35      m      42139           1035849600           0
# 1206         NaN   -1      n      33103           1035849600          -1
# 2622         NaN   -1    NaN       2030           1037404800          -1
# 2732         NaN   -1      n        147           1037577600          -1
# 3653          UK   31      m      18504           1041033600           0
# ...          ...  ...    ...        ...                  ...         ...
# 50871714      BY   19      f        569           1342728447          55
# 50900118      RU   19      m         96           1342887305          12
# 50931921     NaN   -1      m        221           1343064308          -1
# 50933471     NaN   -1      n         49           1343071062          -1
# 50967444     NaN   16      n        262           1343250546          -1
#
#           gender_id  novelty_artist_avg_month  novelty_artist_avg_6months  \
# user_id
# 384               0                  0.276629                    0.044439
# 1206              1                  0.437224                    0.109671
# 2622             -1                  0.604828                    0.043923
# 2732              1                  0.756973                    0.020071
# 3653              0                  0.380005                    0.045207
# ...             ...                       ...                         ...
# 50871714          2                  0.417087                    0.035417
# 50900118          0                  0.566328                    0.032624
# 50931921          0                  0.483171                    0.032946
# 50933471          1                  0.559632                    0.026570
# 50967444          1                  0.263945                    0.059712
#
#           novelty_artist_avg_year  mainstreaminess_avg_month  \
# user_id
# 384                      0.309429                   0.024655
# 1206                     0.513787                   0.181991
# 2622                     0.698983                   0.052310
# 2732                     0.882801                   0.005092
# 3653                     0.424411                   0.042821
# ...                           ...                        ...
# 50871714                 0.549888                   0.084304
# 50900118                 0.680317                   0.049010
# 50931921                 0.351648                   0.038075
# 50933471                 0.599199                   0.040033
# 50967444                 0.512946                   0.115332
#
#           mainstreaminess_avg_6months  mainstreaminess_avg_year  \
# user_id
# 384                          0.367343                  0.000000
# 1206                         0.391304                  0.000000
# 2622                         0.780064                  0.079669
# 2732                         0.886364                  0.032614
# 3653                         0.491756                  0.077731
# ...                               ...                       ...
# 50871714                     0.662491                  0.075544
# 50900118                     0.827854                  0.103613
# 50931921                     0.382353                  0.012505
# 50933471                     0.656787                  0.039335
# 50967444                     0.701197                  0.089394
#
#           mainstreaminess_global  cnt_listeningevents  cnt_distinct_tracks  \
# user_id
# 384                     0.124903              17198.0               3601.0
# 1206                    0.343855              17967.0              10990.0
# 2622                    0.245980               3939.0               3084.0
# 2732                    0.077512                234.0                202.0
# 3653                    0.207567              18238.0               9839.0
# ...                          ...                  ...                  ...
# 50871714                0.160736              26932.0               6837.0
# 50900118                0.145418               7174.0               3970.0
# 50931921                0.136102                998.0                676.0
# 50933471                0.175908               4152.0               2845.0
# 50967444                0.247454              34440.0              10080.0
#
#           cnt_distinct_artists  cnt_listeningevents_per_week  \
# user_id
# 384                      330.0                      196.2290
# 1206                    1693.0                      265.1490
# 2622                    1176.0                       22.8009
# 2732                     112.0                        1.1455
# 3653                    2151.0                       41.8051
# ...                        ...                           ...
# 50871714                1154.0                      244.3810
# 50900118                 547.0                       76.4347
# 50931921                 155.0                       12.9569
# 50933471                 475.0                       38.5342
# 50967444                 686.0                      314.1850
#
#           relative_le_per_weekday1  relative_le_per_weekday2  \
# user_id
# 384                         0.1828                    0.1513
# 1206                        0.1679                    0.1850
# 2622                        0.1813                    0.1318
# 2732                        0.0214                    0.0726
# 3653                        0.1164                    0.1545
# ...                            ...                       ...
# 50871714                    0.1765                    0.1437
# 50900118                    0.1398                    0.1280
# 50931921                    0.2695                    0.0341
# 50933471                    0.1419                    0.1202
# 50967444                    0.1298                    0.1414
#
#           relative_le_per_weekday3  relative_le_per_weekday4  \
# user_id
# 384                         0.1361                    0.1252
# 1206                        0.1815                    0.1640
# 2622                        0.1181                    0.1442
# 2732                        0.0940                    0.2778
# 3653                        0.1316                    0.1380
# ...                            ...                       ...
# 50871714                    0.1091                    0.1272
# 50900118                    0.1310                    0.1469
# 50931921                    0.0932                    0.1453
# 50933471                    0.1525                    0.1185
# 50967444                    0.1477                    0.1380
#
#           relative_le_per_weekday5  relative_le_per_weekday6  \
# user_id
# 384                         0.1318                    0.1286
# 1206                        0.1542                    0.0700
# 2622                        0.1775                    0.1084
# 2732                        0.0171                    0.2564
# 3653                        0.1580                    0.1745
# ...                            ...                       ...
# 50871714                    0.1750                    0.1444
# 50900118                    0.1450                    0.1415
# 50931921                    0.0611                    0.0992
# 50933471                    0.1373                    0.1168
# 50967444                    0.1441                    0.1545
#
#           relative_le_per_weekday7  relative_le_per_hour0  \
# user_id
# 384                         0.1443                 0.0850
# 1206                        0.0773                 0.0539
# 2622                        0.1389                 0.0074
# 2732                        0.2607                    NaN
# 3653                        0.1270                 0.0612
# ...                            ...                    ...
# 50871714                    0.1241                 0.0568
# 50900118                    0.1678                 0.0375
# 50931921                    0.2976                    NaN
# 50933471                    0.2129                 0.0539
# 50967444                    0.1445                 0.0650
#
#           relative_le_per_hour1  relative_le_per_hour2  relative_le_per_hour3  \
# user_id
# 384                      0.1169                 0.1101                 0.0984
# 1206                     0.0371                 0.0321                 0.0245
# 2622                     0.0053                 0.0036                 0.0005
# 2732                        NaN                    NaN                    NaN
# 3653                     0.0392                 0.0249                 0.0250
# ...                         ...                    ...                    ...
# 50871714                 0.0440                 0.0292                 0.0197
# 50900118                 0.0162                 0.0057                 0.0163
# 50931921                 0.0010                    NaN                    NaN
# 50933471                 0.0349                 0.0248                 0.0084
# 50967444                 0.0711                 0.0913                 0.0947
#
#           relative_le_per_hour4  relative_le_per_hour5  relative_le_per_hour6  \
# user_id
# 384                      0.0781                 0.0500                 0.0145
# 1206                     0.0322                 0.0368                 0.0366
# 2622                     0.0003                 0.0008                 0.0003
# 2732                        NaN                    NaN                    NaN
# 3653                     0.0169                 0.0105                 0.0088
# ...                         ...                    ...                    ...
# 50871714                 0.0138                 0.0111                 0.0118
# 50900118                 0.0114                 0.0121                 0.0107
# 50931921                    NaN                    NaN                    NaN
# 50933471                 0.0007                 0.0010                 0.0022
# 50967444                 0.0746                 0.0534                 0.0362
#
#           relative_le_per_hour7  relative_le_per_hour8  relative_le_per_hour9  \
# user_id
# 384                      0.0051                 0.0006                 0.0012
# 1206                     0.0460                 0.0257                 0.0041
# 2622                     0.0003                 0.0008                 0.0025
# 2732                        NaN                 0.0128                 0.0342
# 3653                     0.0063                 0.0086                 0.0206
# ...                         ...                    ...                    ...
# 50871714                 0.0140                 0.0176                 0.0265
# 50900118                 0.0110                 0.0360                 0.0407
# 50931921                    NaN                    NaN                 0.0130
# 50933471                    NaN                    NaN                 0.0026
# 50967444                 0.0226                 0.0145                 0.0083
#
#           relative_le_per_hour10  relative_le_per_hour11  \
# user_id
# 384                       0.0079                  0.0051
# 1206                      0.0014                     NaN
# 2622                      0.0279                  0.0678
# 2732                      0.0342                  0.1410
# 3653                      0.0117                  0.0198
# ...                          ...                     ...
# 50871714                  0.0314                  0.0420
# 50900118                  0.0514                  0.0489
# 50931921                  0.0190                  0.0641
# 50933471                  0.0079                  0.0282
# 50967444                  0.0070                  0.0069
#
#           relative_le_per_hour12  relative_le_per_hour13  \
# user_id
# 384                       0.0091                  0.0209
# 1206                         NaN                  0.0003
# 2622                      0.0675                  0.1285
# 2732                      0.1154                  0.1368
# 3653                      0.0434                  0.0495
# ...                          ...                     ...
# 50871714                  0.0554                  0.0567
# 50900118                  0.0473                  0.0415
# 50931921                  0.0832                  0.0681
# 50933471                  0.0537                  0.0354
# 50967444                  0.0070                  0.0084
#
#           relative_le_per_hour14  relative_le_per_hour15  \
# user_id
# 384                       0.0279                  0.0410
# 1206                      0.0016                  0.0115
# 2622                      0.1320                  0.0493
# 2732                      0.0598                  0.0726
# 3653                      0.0541                  0.0518
# ...                          ...                     ...
# 50871714                  0.0542                  0.0529
# 50900118                  0.0397                  0.0431
# 50931921                  0.0561                  0.1172
# 50933471                  0.0417                  0.0347
# 50967444                  0.0153                  0.0292
#
#           relative_le_per_hour16  relative_le_per_hour17  \
# user_id
# 384                       0.0811                  0.1506
# 1206                      0.0276                  0.0662
# 2622                      0.0317                  0.0470
# 2732                      0.0171                  0.0342
# 3653                      0.0564                  0.0554
# ...                          ...                     ...
# 50871714                  0.0575                  0.0558
# 50900118                  0.0587                  0.0733
# 50931921                  0.1723                  0.1062
# 50933471                  0.0294                  0.0236
# 50967444                  0.0422                  0.0438
#
#           relative_le_per_hour18  relative_le_per_hour19  \
# user_id
# 384                       0.0377                  0.0298
# 1206                      0.0790                  0.0838
# 2622                      0.0658                  0.1127
# 2732                      0.0769                  0.1453
# 3653                      0.0849                  0.0954
# ...                          ...                     ...
# 50871714                  0.0578                  0.0573
# 50900118                  0.0843                  0.0764
# 50931921                  0.0892                  0.1092
# 50933471                  0.0508                  0.0763
# 50967444                  0.0547                  0.0508
#
#           relative_le_per_hour20  relative_le_per_hour21  \
# user_id
# 384                       0.0132                  0.0007
# 1206                      0.0995                  0.1195
# 2622                      0.1112                  0.0680
# 2732                      0.0470                  0.0513
# 3653                      0.0833                  0.0657
# ...                          ...                     ...
# 50871714                  0.0515                  0.0551
# 50900118                  0.0728                  0.0643
# 50931921                  0.0621                  0.0120
# 50933471                  0.1086                  0.1419
# 50967444                  0.0428                  0.0460
#
#           relative_le_per_hour22  relative_le_per_hour23
# user_id
# 384                       0.0001                  0.0151
# 1206                      0.0968                  0.0839
# 2622                      0.0437                  0.0254
# 2732                      0.0085                  0.0128
# 3653                      0.0471                  0.0595
# ...                          ...                     ...
# 50871714                  0.0639                  0.0641
# 50900118                  0.0555                  0.0452
# 50931921                  0.0210                  0.0060
# 50933471                  0.1387                  0.1004
# 50967444                  0.0575                  0.0568
#
# [119555 rows x 49 columns]

# %%
complete_train_df = pd.merge(train, dataset.df_users.reset_index(), how='left', on='user_id')

X_cols = [c for c in complete_train_df.columns if c.startswith('relative')]

# %%
X_cols = [c for c in complete_train_df.columns if c.startswith('relative_per_week') or c.startswith('mainstreaminess')
            or c.startswith('novelty')] + ['age', 'gender_id']

# %%
X_cols
# Out:
# ['novelty_artist_avg_month',
#  'novelty_artist_avg_6months',
#  'novelty_artist_avg_year',
#  'mainstreaminess_avg_month',
#  'mainstreaminess_avg_6months',
#  'mainstreaminess_avg_year',
#  'mainstreaminess_global',
#  'age',
#  'gender_id']

# %%
dataset.df_users.index.nunique()
# Out:
# 119555

# %%
complete_train_df['user_id'].nunique()
# Out:
# 29730

# %%
complete_train_df[X_cols].drop_duplicates().shape
# Out:
# (29730, 9)

# %% [markdown]
# ## K-Nearest Neighbors

# %%
from sklearn.cluster import DBSCAN

# %%
class DBSCANModel(RecModel):
    
    def __init__(self, items: pd.DataFrame,
                 users: pd.DataFrame, top_k: int=100, **kwargs):
        super(DBSCANModel, self).__init__()
        self.items = items
        self.users = users
        self.top_k = top_k
        self.X_cols = ['novelty_artist_avg_month',
                 'novelty_artist_avg_6months',
                 'novelty_artist_avg_year',
                 'mainstreaminess_avg_month',
                 'mainstreaminess_avg_6months',
                 'mainstreaminess_avg_year',
                 'mainstreaminess_global',
                 'age',
                 'gender_id'
                 ]
        # kwargs may contain additional arguments in case, for example, you
        # have data augmentation strategies
        print("Received additional arguments: {}".format(kwargs))
        return

    def train(self, train_df: pd.DataFrame):
        """
        Implement here your training logic. Since our example method is a simple random model,
        we actually don't use any training data to build the model, but you should ;-)

        At the end of training, make sure the class contains a trained model you can use in the predict method.
        """
        
        X_cluster_df = self.users[self.X_cols].fillna(self.users[self.X_cols].mean())
        
        
        
        self.clustering = DBSCAN()
        self.users['pred_cluster'] = self.clustering.fit_predict(X_cluster_df)
        
        self.complete_df = pd.merge(train_df, self.users.reset_index()[['user_id', 'pred_cluster']], on='user_id', how='left')
        
        
        print("Training completed!")
        return 

    def predict(self, user_ids: pd.DataFrame) -> pd.DataFrame:
        """
        
        This function takes as input all the users that we want to predict the top-k items for, and 
        returns all the predicted songs.

        While in this example is just a random generator, the same logic in your implementation 
        would allow for batch predictions of all the target data points.
        
        """
        k = self.top_k
        num_users = len(user_ids)
        
        
        
        cluster_tracks_df = pd.DataFrame(self.complete_df.groupby(['pred_cluster', 'track_id'])['user_track_count'].sum()).reset_index()
        
        users_lsts = []
        for user in user_ids['user_id'].tolist():
            user_cluster = self.users.loc[user]['pred_cluster']
            user_cluster_tracks = cluster_tracks_df[cluster_tracks_df['pred_cluster'] == user_cluster][['track_id', 'user_track_count']]
            
            track_counts = user_cluster_tracks['user_track_count']
            
            track_counts_n = track_counts / np.linalg.norm(track_counts, ord=1)
            
            suggested_tracks = np.random.choice(user_cluster_tracks['track_id'], k, p=track_counts_n)
            
            user_dict = {'user_id': user}
            for i in range(k):
                user_dict[str(i)] = suggested_tracks[i]
            
            users_lsts.append(user_dict)
        
        
        output_df = pd.DataFrame(users_lsts)

        users_df = output_df.set_index('user_id')
        return users_df

# %%
dbscan_runner = CustomRunner(
    dataset=dataset,
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY,
    participant_id=PARTICIPANT_ID,
    bucket_name=BUCKET_NAME,
    email=EMAIL
    )

# %%
my_model = DBSCANModel(
    items=dataset.df_tracks,
    users=dataset.df_users
)
# Out:
# Received additional arguments: {}

# %%
# r = dbscan_runner.evaluate(model=my_model, limit=0)
